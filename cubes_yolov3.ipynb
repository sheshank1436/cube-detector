# %% [markdown]
# <a href="https://colab.research.google.com/github/sheshank1436/cube-detector/blob/main/cubes_yolov3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# 'Colab Notebooks'   darknet	    'My Drive'	 yolo1
#  cube		    darknet-master   pdf	 yolov3
#  cubes_yolo	   'img_(162).jpg'   test.jpeg	 yolov3-tiger

# %%
import os
os.getcwd()
# Out:
# '/content/gdrive/My Drive/darknet'

# %%
# %cd /content/gdrive/MyDrive/darknet
# Out:
# /content/gdrive/MyDrive/darknet

# %%
# !make &> compile.log

# %%
# !chmod +x ./darknet

# %%
# Start the training
# !./darknet detector train data/obj.data cfg/yolov3_custom_train.cfg  darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 27192, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 0.000677, iou_loss = 0.000000, total_loss = 0.000677
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.795761), count: 2, class_loss = 0.199116, iou_loss = 0.164634, total_loss = 0.363750
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.519307), count: 1, class_loss = 0.333497, iou_loss = 0.208217, total_loss = 0.541714
#  total_bbox = 27195, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.764417), count: 1, class_loss = 0.000263, iou_loss = 0.051027, total_loss = 0.051290
# ...
