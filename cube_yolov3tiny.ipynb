# %% [markdown]
# <a href="https://colab.research.google.com/github/sheshank1436/cube-detector/blob/main/cube_yolov3tiny.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# 'Colab Notebooks'   darknet	    'My Drive'	 yolo1
#  cube		    darknet-master   pdf	 yolov3
#  cubes_yolo	   'img_(162).jpg'   test.jpeg	 yolov3-tiger

# %%
# %cd /content/gdrive/MyDrive/darknet
# Out:
# /content/gdrive/MyDrive/darknet

# %%
# !make
# Out:
# chmod +x *.sh

# %%
import os 
os.getcwd()
# Out:
# '/content/gdrive/My Drive/darknet'

# %%
os.listdir(r'data/images')
# Out:
# ['image181.txt',
#  'image240.txt',
#  'image213.jpg',
#  'image213.txt',
#  'image167.txt',
#  'aimage461.jpg',
#  'aimage461.txt',
#  'aimage42.txt',
#  'aimage428.txt',
#  'aimage35.txt',
#  'aimage329.txt',
#  'aimage319.txt',
#  'aimage428.jpg',
#  'aimage42.jpg',
#  'aimage35.jpg',
#  'aimage319.jpg',
#  'aimage329.jpg',
#  'aimage284.txt',
#  'aimage244.txt',
#  'aimage23.txt',
#  'aimage205.txt',
#  'aimage284.jpg',
#  'aimage244.jpg',
#  'aimage204.jpg',
#  'aimage205.jpg',
#  'aimage23.jpg',
#  'aimage194.txt',
#  'aimage202.txt',
#  'aimage187.txt',
#  'aimage152.txt',
#  'aimage155.txt',
#  'aimage204.txt',
#  'aimage202.jpg',
#  'aimage194.jpg',
#  'aimage187.jpg',
#  'aimage155.jpg',
#  'aimage152.jpg',
#  'nimage145.txt',
#  'nimage135.txt',
#  'nimage120.txt',
#  'nimage135.jpg',
#  'nimage145.jpg',
#  'image496.txt',
#  'nimage116.txt',
#  'nimage111.txt',
#  'nimage115.txt',
#  'image492.txt',
#  'nimage120.jpg',
#  'nimage116.jpg',
#  'nimage115.jpg',
# ...

# %%
import os
import glob
print(os.getcwd())
txt_file_paths = glob.glob(r"data/images/*.txt")
(txt_file_paths)
# Out:
# /content/gdrive/My Drive/darknet
# ['data/images/image181.txt',
#  'data/images/image240.txt',
#  'data/images/image213.txt',
#  'data/images/image167.txt',
#  'data/images/aimage461.txt',
#  'data/images/aimage42.txt',
#  'data/images/aimage428.txt',
#  'data/images/aimage35.txt',
#  'data/images/aimage329.txt',
#  'data/images/aimage319.txt',
#  'data/images/aimage284.txt',
#  'data/images/aimage244.txt',
#  'data/images/aimage23.txt',
#  'data/images/aimage205.txt',
#  'data/images/aimage194.txt',
#  'data/images/aimage202.txt',
#  'data/images/aimage187.txt',
#  'data/images/aimage152.txt',
#  'data/images/aimage155.txt',
#  'data/images/aimage204.txt',
#  'data/images/nimage145.txt',
#  'data/images/nimage135.txt',
#  'data/images/nimage120.txt',
#  'data/images/image496.txt',
#  'data/images/nimage116.txt',
#  'data/images/nimage111.txt',
#  'data/images/nimage115.txt',
#  'data/images/image492.txt',
#  'data/images/image428.txt',
#  'data/images/image432.txt',
# ...

# %%
# We're going to convert the class index on the .txt files. As we're working with only one class, it's supposed to be class 0.
# If the index is different from 0 then we're going to change it.
import glob
import os
import re

txt_file_paths = glob.glob(r"data/images/*.txt")
for i, file_path in enumerate(txt_file_paths):
    # get image size
    with open(file_path, "r") as f_o:
        lines = f_o.readlines()

        text_converted = []
        for line in lines:
            print(line)
            numbers = re.findall("[0-9.]+", line)
            print(numbers)
            if numbers:

                # Define coordinates
                text = "{} {} {} {} {}".format(0, numbers[1], numbers[2], numbers[3], numbers[4])
                text_converted.append(text)
                print(i, file_path)
                print(text)
        # Write file
        with open(file_path, 'w') as fp:
            for item in text_converted:
                fp.writelines("%s\n" % item)
# Out:
# 0 0.325721 0.552885 0.189904 0.302885
#
# ['0', '0.325721', '0.552885', '0.189904', '0.302885']
# 0 data/images/image181.txt
# 0 0.325721 0.552885 0.189904 0.302885
# 0 0.387019 0.492788 0.173077 0.250000
#
# ['0', '0.387019', '0.492788', '0.173077', '0.250000']
# 1 data/images/image240.txt
# 0 0.387019 0.492788 0.173077 0.250000
# 0 0.394231 0.614183 0.19710 0.295673
#
# ['0', '0.394231', '0.614183', '0.19710', '0.295673']
# 2 data/images/image213.txt
# 0 0.394231 0.614183 0.19710 0.295673
# 0 0.638221 0.558894 0.084135 0.117788
#
# ['0', '0.638221', '0.558894', '0.084135', '0.117788']
# 3 data/images/image167.txt
# 0 0.638221 0.558894 0.084135 0.117788
# 0 0.699519 0.358173 0.480769 0.668269
#
# ['0', '0.699519', '0.358173', '0.480769', '0.668269']
# 4 data/images/aimage461.txt
# 0 0.699519 0.358173 0.480769 0.668269
# 0 0.481971 0.38460 0.281250 0.307692
#
# ['0', '0.481971', '0.38460', '0.281250', '0.307692']
# 5 data/images/aimage42.txt
# 0 0.481971 0.38460 0.281250 0.307692
# ...

# %%
import glob
images_list = glob.glob("data/images/*.jpg")
print(images_list)
# Out:
# ['data/images/image213.jpg', 'data/images/aimage461.jpg', 'data/images/aimage428.jpg', 'data/images/aimage42.jpg', 'data/images/aimage35.jpg', 'data/images/aimage319.jpg', 'data/images/aimage329.jpg', 'data/images/aimage284.jpg', 'data/images/aimage244.jpg', 'data/images/aimage204.jpg', 'data/images/aimage205.jpg', 'data/images/aimage23.jpg', 'data/images/aimage202.jpg', 'data/images/aimage194.jpg', 'data/images/aimage187.jpg', 'data/images/aimage155.jpg', 'data/images/aimage152.jpg', 'data/images/nimage135.jpg', 'data/images/nimage145.jpg', 'data/images/nimage120.jpg', 'data/images/nimage116.jpg', 'data/images/nimage115.jpg', 'data/images/nimage111.jpg', 'data/images/image496.jpg', 'data/images/image492.jpg', 'data/images/image477.jpg', 'data/images/image466.jpg', 'data/images/image432.jpg', 'data/images/image428.jpg', 'data/images/image396.jpg', 'data/images/image309.jpg', 'data/images/image332.jpg', 'data/images/image388.jpg', 'data/images/image282.jpg', 'data/images/image262.jpg'
# ...

# %%
#Create training.txt file
file = open("data/train.txt", "w") 
file.write("\n".join(images_list)) 
file.close()

# %%
# Start the training
# !./darknet detector train data/obj.data cfg/yolov3-tiny-custom.cfg  darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 41843, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.000000), count: 1, class_loss = 0.005381, iou_loss = 0.000000, total_loss = 0.005381
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.669157), count: 4, class_loss = 0.635035, iou_loss = 0.348989, total_loss = 0.984023
#  total_bbox = 41847, rewritten_bbox = 0.000000 %
#
#  5475: 0.421383, 0.226274 avg loss, 0.000010 rate, 0.052065 seconds, 43800 images, 0.017710 hours left
# Loaded: 0.026705 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.839814), count: 3, class_loss = 0.079173, iou_loss = 0.069541, total_loss = 0.148714
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.658174), count: 1, class_loss = 0.092841, iou_loss = 0.056306, total_loss = 0.149148
# ...

# %%
# Start the training
# !./darknet detector train data/obj.data cfg/yolov3-tiny-custom.cfg  /content/gdrive/MyDrive/cube/yolov3-tiny-custom_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 26546, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.873363), count: 4, class_loss = 0.102789, iou_loss = 0.058852, total_loss = 0.161641
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.000000), count: 1, class_loss = 0.000371, iou_loss = 0.000000, total_loss = 0.000371
#  total_bbox = 26550, rewritten_bbox = 0.000000 %
#
#  9475: 0.100044, 0.175608 avg loss, 0.000010 rate, 0.122265 seconds, 75800 images, 0.017285 hours left
# Loaded: 0.001367 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.900361), count: 3, class_loss = 0.012781, iou_loss = 0.100858, total_loss = 0.113638
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.783689), count: 1, class_loss = 0.178851, iou_loss = 0.028185, total_loss = 0.207036
# ...
